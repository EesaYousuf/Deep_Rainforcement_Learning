# %% [markdown]
# 1.DQN for CartPole

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque

# %%
#  Define the Q-Network
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_dim, 24),
            nn.ReLU(),
            nn.Linear(24, 24),
            nn.ReLU(),
            nn.Linear(24, action_dim)
        )
        
    def forward(self, x):
        return self.fc(x)

# %%
# Experience Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity=10000):
        self.buffer = deque(maxlen=capacity)

    def push(self, transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)
    def __len__(self):
        return len(self.buffer)

# %%
# Hyperparameters
env = gym.make("CartPole-v1")
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

gamma = 0.99
epsilon = 1.0
epsilon_decay = 0.995
epsilon_min = 0.01
lr = 1e-3
batch_size = 64
episodes = 500

# %%
# Initialize
policy_net = DQN(state_dim, action_dim)
target_net = DQN(state_dim, action_dim)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.Adam(policy_net.parameters(), lr=lr)
replay_buffer = ReplayBuffer()

def choose_action(state):
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        return policy_net(state_tensor).argmax().item()

# %%
# Training loop
for episode in range(episodes):
    state = env.reset()[0]
    total_reward = 0

    for t in range(200):
        action = choose_action(state)
        next_state, reward, done, _, _ = env.step(action)
        replay_buffer.push((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward

        if len(replay_buffer) > batch_size:
            batch = replay_buffer.sample(batch_size)
            states, actions, rewards, next_states, dones = zip(*batch)

            states = torch.FloatTensor(states)
            actions = torch.LongTensor(actions).unsqueeze(1)
            rewards = torch.FloatTensor(rewards).unsqueeze(1)
            next_states = torch.FloatTensor(next_states)
            dones = torch.BoolTensor(dones).unsqueeze(1)

            q_values = policy_net(states).gather(1, actions)
            next_q_values = target_net(next_states).max(1)[0].unsqueeze(1)
            target_q = rewards + gamma * next_q_values * (~dones)

            loss = nn.MSELoss()(q_values, target_q)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        if done:
            break

    # Update epsilon
    epsilon = max(epsilon_min, epsilon * epsilon_decay)

    # Update target network
    if episode % 10 == 0:
        target_net.load_state_dict(policy_net.state_dict())

    print(f"Episode {episode}, Total Reward: {total_reward}, Epsilon: {epsilon:.2f}")

env.close()
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# C:\Users\HP\AppData\Local\Temp\ipykernel_12220\106987893.py:17: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   states = torch.FloatTensor(states)
# Episode 0, Total Reward: 82.0, Epsilon: 0.99
# Episode 1, Total Reward: 29.0, Epsilon: 0.99
# Episode 2, Total Reward: 18.0, Epsilon: 0.99
# Episode 3, Total Reward: 20.0, Epsilon: 0.98
# Episode 4, Total Reward: 13.0, Epsilon: 0.98
# Episode 5, Total Reward: 16.0, Epsilon: 0.97
# Episode 6, Total Reward: 16.0, Epsilon: 0.97
# Episode 7, Total Reward: 27.0, Epsilon: 0.96
# Episode 8, Total Reward: 16.0, Epsilon: 0.96
# Episode 9, Total Reward: 16.0, Epsilon: 0.95
# Episode 10, Total Reward: 10.0, Epsilon: 0.95
# Episode 11, Total Reward: 21.0, Epsilon: 0.94
# Episode 12, Total Reward: 42.0, Epsilon: 0.94
# Episode 13, Total Reward: 25.0, Epsilon: 0.93
# Episode 14, Total Reward: 11.0, Epsilon: 0.93
# Episode 15, Total Reward: 13.0, Epsilon: 0.92
# Episode 16, Total Reward: 25.0, Epsilon: 0.92
# Episode 17, Total Reward: 17.0, Epsilon: 0.91
# Episode 18, Total Reward: 21.0, Epsilon: 0.91
# Episode 19, Total Reward: 12.0, Epsilon: 0.90
# Episode 20, Total Reward: 15.0, Epsilon: 0.90
# Episode 21, Total Reward: 15.0, Epsilon: 0.90
# Episode 22, Total Reward: 14.0, Epsilon: 0.89
# Episode 23, Total Reward: 10.0, Epsilon: 0.89
# Episode 24, Total Reward: 19.0, Epsilon: 0.88
# Episode 25, Total Reward: 47.0, Epsilon: 0.88
# Episode 26, Total Reward: 15.0, Epsilon: 0.87
# Episode 27, Total Reward: 11.0, Epsilon: 0.87
# Episode 28, Total Reward: 10.0, Epsilon: 0.86
# Episode 29, Total Reward: 14.0, Epsilon: 0.86
# Episode 30, Total Reward: 11.0, Epsilon: 0.86
# Episode 31, Total Reward: 27.0, Epsilon: 0.85
# Episode 32, Total Reward: 28.0, Epsilon: 0.85
# Episode 33, Total Reward: 14.0, Epsilon: 0.84
# Episode 34, Total Reward: 32.0, Epsilon: 0.84
# Episode 35, Total Reward: 24.0, Epsilon: 0.83
# Episode 36, Total Reward: 26.0, Epsilon: 0.83
# Episode 37, Total Reward: 13.0, Epsilon: 0.83
# Episode 38, Total Reward: 12.0, Epsilon: 0.82
# Episode 39, Total Reward: 34.0, Epsilon: 0.82
# Episode 40, Total Reward: 28.0, Epsilon: 0.81
# Episode 41, Total Reward: 27.0, Epsilon: 0.81
# Episode 42, Total Reward: 23.0, Epsilon: 0.81
# Episode 43, Total Reward: 14.0, Epsilon: 0.80
# Episode 44, Total Reward: 27.0, Epsilon: 0.80
# Episode 45, Total Reward: 34.0, Epsilon: 0.79
# Episode 46, Total Reward: 14.0, Epsilon: 0.79
# Episode 47, Total Reward: 12.0, Epsilon: 0.79
# Episode 48, Total Reward: 34.0, Epsilon: 0.78
# Episode 49, Total Reward: 14.0, Epsilon: 0.78
# Episode 50, Total Reward: 38.0, Epsilon: 0.77
# Episode 51, Total Reward: 52.0, Epsilon: 0.77
# Episode 52, Total Reward: 22.0, Epsilon: 0.77
# Episode 53, Total Reward: 72.0, Epsilon: 0.76
# Episode 54, Total Reward: 23.0, Epsilon: 0.76
# Episode 55, Total Reward: 18.0, Epsilon: 0.76
# Episode 56, Total Reward: 11.0, Epsilon: 0.75
# Episode 57, Total Reward: 25.0, Epsilon: 0.75
# Episode 58, Total Reward: 29.0, Epsilon: 0.74
# Episode 59, Total Reward: 21.0, Epsilon: 0.74
# Episode 60, Total Reward: 25.0, Epsilon: 0.74
# Episode 61, Total Reward: 18.0, Epsilon: 0.73
# Episode 62, Total Reward: 18.0, Epsilon: 0.73
# Episode 63, Total Reward: 37.0, Epsilon: 0.73
# Episode 64, Total Reward: 52.0, Epsilon: 0.72
# Episode 65, Total Reward: 21.0, Epsilon: 0.72
# Episode 66, Total Reward: 36.0, Epsilon: 0.71
# Episode 67, Total Reward: 23.0, Epsilon: 0.71
# Episode 68, Total Reward: 19.0, Epsilon: 0.71
# Episode 69, Total Reward: 57.0, Epsilon: 0.70
# Episode 70, Total Reward: 34.0, Epsilon: 0.70
# Episode 71, Total Reward: 45.0, Epsilon: 0.70
# Episode 72, Total Reward: 12.0, Epsilon: 0.69
# Episode 73, Total Reward: 30.0, Epsilon: 0.69
# Episode 74, Total Reward: 135.0, Epsilon: 0.69
# Episode 75, Total Reward: 62.0, Epsilon: 0.68
# Episode 76, Total Reward: 100.0, Epsilon: 0.68
# Episode 77, Total Reward: 43.0, Epsilon: 0.68
# Episode 78, Total Reward: 82.0, Epsilon: 0.67
# Episode 79, Total Reward: 176.0, Epsilon: 0.67
# Episode 80, Total Reward: 100.0, Epsilon: 0.67
# Episode 81, Total Reward: 74.0, Epsilon: 0.66
# Episode 82, Total Reward: 71.0, Epsilon: 0.66
# Episode 83, Total Reward: 100.0, Epsilon: 0.66
# Episode 84, Total Reward: 48.0, Epsilon: 0.65
# Episode 85, Total Reward: 29.0, Epsilon: 0.65
# Episode 86, Total Reward: 41.0, Epsilon: 0.65
# Episode 87, Total Reward: 73.0, Epsilon: 0.64
# Episode 88, Total Reward: 55.0, Epsilon: 0.64
# Episode 89, Total Reward: 146.0, Epsilon: 0.64
# Episode 90, Total Reward: 39.0, Epsilon: 0.63
# Episode 91, Total Reward: 12.0, Epsilon: 0.63
# Episode 92, Total Reward: 78.0, Epsilon: 0.63
# Episode 93, Total Reward: 18.0, Epsilon: 0.62
# Episode 94, Total Reward: 15.0, Epsilon: 0.62
# Episode 95, Total Reward: 65.0, Epsilon: 0.62
# Episode 96, Total Reward: 139.0, Epsilon: 0.61
# Episode 97, Total Reward: 47.0, Epsilon: 0.61
# Episode 98, Total Reward: 55.0, Epsilon: 0.61
# Episode 99, Total Reward: 19.0, Epsilon: 0.61
# Episode 100, Total Reward: 45.0, Epsilon: 0.60
# Episode 101, Total Reward: 94.0, Epsilon: 0.60
# Episode 102, Total Reward: 11.0, Epsilon: 0.60
# Episode 103, Total Reward: 38.0, Epsilon: 0.59
# Episode 104, Total Reward: 86.0, Epsilon: 0.59
# Episode 105, Total Reward: 46.0, Epsilon: 0.59
# Episode 106, Total Reward: 43.0, Epsilon: 0.58
# Episode 107, Total Reward: 31.0, Epsilon: 0.58
# Episode 108, Total Reward: 79.0, Epsilon: 0.58
# Episode 109, Total Reward: 80.0, Epsilon: 0.58
# Episode 110, Total Reward: 61.0, Epsilon: 0.57
# Episode 111, Total Reward: 124.0, Epsilon: 0.57
# Episode 112, Total Reward: 64.0, Epsilon: 0.57
# Episode 113, Total Reward: 17.0, Epsilon: 0.56
# Episode 114, Total Reward: 44.0, Epsilon: 0.56
# Episode 115, Total Reward: 42.0, Epsilon: 0.56
# Episode 116, Total Reward: 150.0, Epsilon: 0.56
# Episode 117, Total Reward: 108.0, Epsilon: 0.55
# Episode 118, Total Reward: 74.0, Epsilon: 0.55
# Episode 119, Total Reward: 200.0, Epsilon: 0.55
# Episode 120, Total Reward: 93.0, Epsilon: 0.55
# Episode 121, Total Reward: 200.0, Epsilon: 0.54
# Episode 122, Total Reward: 155.0, Epsilon: 0.54
# Episode 123, Total Reward: 61.0, Epsilon: 0.54
# Episode 124, Total Reward: 57.0, Epsilon: 0.53
# Episode 125, Total Reward: 74.0, Epsilon: 0.53
# Episode 126, Total Reward: 106.0, Epsilon: 0.53
# Episode 127, Total Reward: 200.0, Epsilon: 0.53
# Episode 128, Total Reward: 180.0, Epsilon: 0.52
# Episode 129, Total Reward: 134.0, Epsilon: 0.52
# Episode 130, Total Reward: 146.0, Epsilon: 0.52
# Episode 131, Total Reward: 104.0, Epsilon: 0.52
# Episode 132, Total Reward: 38.0, Epsilon: 0.51
# Episode 133, Total Reward: 200.0, Epsilon: 0.51
# Episode 134, Total Reward: 105.0, Epsilon: 0.51
# Episode 135, Total Reward: 76.0, Epsilon: 0.51
# Episode 136, Total Reward: 29.0, Epsilon: 0.50
# Episode 137, Total Reward: 137.0, Epsilon: 0.50
# Episode 138, Total Reward: 200.0, Epsilon: 0.50
# Episode 139, Total Reward: 56.0, Epsilon: 0.50
# Episode 140, Total Reward: 37.0, Epsilon: 0.49
# Episode 141, Total Reward: 200.0, Epsilon: 0.49
# Episode 142, Total Reward: 88.0, Epsilon: 0.49
# Episode 143, Total Reward: 163.0, Epsilon: 0.49
# Episode 144, Total Reward: 80.0, Epsilon: 0.48
# Episode 145, Total Reward: 124.0, Epsilon: 0.48
# Episode 146, Total Reward: 40.0, Epsilon: 0.48
# Episode 147, Total Reward: 18.0, Epsilon: 0.48
# Episode 148, Total Reward: 80.0, Epsilon: 0.47
# Episode 149, Total Reward: 200.0, Epsilon: 0.47
# Episode 150, Total Reward: 189.0, Epsilon: 0.47
# Episode 151, Total Reward: 59.0, Epsilon: 0.47
# Episode 152, Total Reward: 86.0, Epsilon: 0.46
# Episode 153, Total Reward: 181.0, Epsilon: 0.46
# Episode 154, Total Reward: 200.0, Epsilon: 0.46
# Episode 155, Total Reward: 200.0, Epsilon: 0.46
# Episode 156, Total Reward: 200.0, Epsilon: 0.46
# Episode 157, Total Reward: 183.0, Epsilon: 0.45
# Episode 158, Total Reward: 42.0, Epsilon: 0.45
# Episode 159, Total Reward: 130.0, Epsilon: 0.45
# Episode 160, Total Reward: 98.0, Epsilon: 0.45
# Episode 161, Total Reward: 200.0, Epsilon: 0.44
# Episode 162, Total Reward: 180.0, Epsilon: 0.44
# Episode 163, Total Reward: 69.0, Epsilon: 0.44
# Episode 164, Total Reward: 30.0, Epsilon: 0.44
# Episode 165, Total Reward: 200.0, Epsilon: 0.44
# Episode 166, Total Reward: 200.0, Epsilon: 0.43
